# %% [markdown]
# # First set of experiments

# %% [markdown]
# # Model ALL-CNN-A

# %%
from test_AllCNN_Models import test_AllCNN_Models
test_AllCNN_Models(model='a')

# %% [markdown]
# Best validation score of 10.310000 % obtained with test performance 14.810000 %

# %% [markdown]
# # Model ALL-CNN-B

# %%
from test_AllCNN_Models import test_AllCNN_Models
test_AllCNN_Models(model='b')

# %% [markdown]
# Best validation score of 11.330000 % obtained with test performance 15.220000 %

# %% [markdown]
# # Model ALL-CNN-C

# %%
from test_AllCNN_Models import test_AllCNN_Models
test_AllCNN_Models(model='c')

# %% [markdown]
# n_train_batches:  250
# n_valid_batches:  50
# n_test_batches:  50
# learning_rate:  0.0500000007451
# ... building the model
# Training Model:  ModelC_AllCNN
# ... training
# epoch 1, minibatch 250/250, validation error 89.970000 %
#      epoch 1, minibatch 250/250, test error of best model 90.000000 %
# epoch 2, minibatch 250/250, validation error 82.250000 %
#      epoch 2, minibatch 250/250, test error of best model 82.070000 %
# epoch 3, minibatch 250/250, validation error 81.340000 %
#      epoch 3, minibatch 250/250, test error of best model 81.390000 %
# epoch 4, minibatch 250/250, validation error 79.120000 %
#      epoch 4, minibatch 250/250, test error of best model 78.830000 %
# epoch 5, minibatch 250/250, validation error 82.110000 %
# epoch 6, minibatch 250/250, validation error 77.880000 %
#      epoch 6, minibatch 250/250, test error of best model 77.480000 %
# epoch 7, minibatch 250/250, validation error 77.530000 %
#      epoch 7, minibatch 250/250, test error of best model 77.350000 %
# epoch 8, minibatch 250/250, validation error 77.780000 %
# epoch 9, minibatch 250/250, validation error 75.110000 %
#      epoch 9, minibatch 250/250, test error of best model 74.700000 %
# epoch 10, minibatch 250/250, validation error 79.950000 %
# epoch 11, minibatch 250/250, validation error 75.640000 %
# epoch 12, minibatch 250/250, validation error 72.210000 %
#      epoch 12, minibatch 250/250, test error of best model 71.760000 %
# epoch 13, minibatch 250/250, validation error 72.490000 %
# epoch 14, minibatch 250/250, validation error 72.780000 %
# epoch 21, minibatch 250/250, validation error 64.420000 %
#      epoch 21, minibatch 250/250, test error of best model 64.520000 %
# epoch 22, minibatch 250/250, validation error 66.630000 %
# epoch 23, minibatch 250/250, validation error 65.960000 %
# epoch 24, minibatch 250/250, validation error 65.770000 %
# epoch 25, minibatch 250/250, validation error 64.680000 %
# epoch 26, minibatch 250/250, validation error 63.740000 %
#      epoch 26, minibatch 250/250, test error of best model 63.860000 %
# epoch 27, minibatch 250/250, validation error 62.330000 %
#      epoch 27, minibatch 250/250, test error of best model 61.800000 %
# epoch 28, minibatch 250/250, validation error 62.420000 %
# epoch 29, minibatch 250/250, validation error 60.360000 %
#      epoch 29, minibatch 250/250, test error of best model 60.860000 %
# epoch 34, minibatch 250/250, validation error 59.440000 %
#      epoch 34, minibatch 250/250, test error of best model 59.520000 %
# epoch 35, minibatch 250/250, validation error 60.230000 %
# epoch 36, minibatch 250/250, validation error 58.080000 %
#      epoch 36, minibatch 250/250, test error of best model 58.130000 %
# epoch 37, minibatch 250/250, validation error 58.940000 %
# epoch 38, minibatch 250/250, validation error 61.360000 %
# epoch 39, minibatch 250/250, validation error 58.330000 %
# epoch 40, minibatch 250/250, validation error 58.660000 %
# epoch 41, minibatch 250/250, validation error 57.860000 %
#      epoch 41, minibatch 250/250, test error of best model 57.130000 %
# epoch 42, minibatch 250/250, validation error 57.390000 %
#      epoch 42, minibatch 250/250, test error of best model 57.340000 %
# epoch 43, minibatch 250/250, validation error 58.700000 %
# epoch 44, minibatch 250/250, validation error 59.460000 %
# epoch 45, minibatch 250/250, validation error 57.860000 %
# epoch 49, minibatch 250/250, validation error 59.010000 %
# epoch 50, minibatch 250/250, validation error 53.650000 %
#      epoch 50, minibatch 250/250, test error of best model 53.720000 %
# epoch 51, minibatch 250/250, validation error 56.090000 %
# epoch 55, minibatch 250/250, validation error 56.440000 %
# epoch 56, minibatch 250/250, validation error 60.940000 %
# epoch 57, minibatch 250/250, validation error 53.970000 %
# epoch 58, minibatch 250/250, validation error 54.850000 %
# epoch 59, minibatch 250/250, validation error 56.590000 %
# epoch 60, minibatch 250/250, validation error 55.600000 %
# epoch 61, minibatch 250/250, validation error 57.050000 %
# epoch 62, minibatch 250/250, validation error 55.010000 %
# epoch 63, minibatch 250/250, validation error 50.780000 %
#      epoch 63, minibatch 250/250, test error of best model 50.990000 %
# epoch 64, minibatch 250/250, validation error 51.230000 %
# epoch 65, minibatch 250/250, validation error 52.330000 %
# epoch 66, minibatch 250/250, validation error 55.900000 %
# epoch 67, minibatch 250/250, validation error 52.890000 %
# epoch 68, minibatch 250/250, validation error 53.080000 %
# epoch 69, minibatch 250/250, validation error 51.590000 %
# epoch 70, minibatch 250/250, validation error 53.430000 %
# epoch 71, minibatch 250/250, validation error 49.510000 %
#      epoch 71, minibatch 250/250, test error of best model 49.400000 %
# epoch 72, minibatch 250/250, validation error 50.500000 %
# epoch 73, minibatch 250/250, validation error 49.700000 %
# epoch 74, minibatch 250/250, validation error 56.450000 %
# epoch 75, minibatch 250/250, validation error 54.390000 %
# epoch 76, minibatch 250/250, validation error 52.810000 %
# epoch 77, minibatch 250/250, validation error 51.160000 %
# epoch 78, minibatch 250/250, validation error 55.080000 %
# epoch 79, minibatch 250/250, validation error 50.640000 %
# epoch 80, minibatch 250/250, validation error 49.020000 %
#      epoch 80, minibatch 250/250, test error of best model 48.690000 %
# epoch 81, minibatch 250/250, validation error 50.520000 %
# epoch 82, minibatch 250/250, validation error 52.430000 %
# epoch 83, minibatch 250/250, validation error 47.340000 %
#      epoch 83, minibatch 250/250, test error of best model 47.400000 %
# epoch 84, minibatch 250/250, validation error 49.290000 %
# epoch 85, minibatch 250/250, validation error 48.730000 %
# epoch 86, minibatch 250/250, validation error 47.360000 %
# epoch 87, minibatch 250/250, validation error 46.800000 %
#      epoch 87, minibatch 250/250, test error of best model 47.210000 %
# epoch 88, minibatch 250/250, validation error 43.090000 %
#      epoch 88, minibatch 250/250, test error of best model 43.510000 %
# epoch 89, minibatch 250/250, validation error 48.720000 %
# epoch 90, minibatch 250/250, validation error 47.280000 %
# epoch 91, minibatch 250/250, validation error 50.450000 %
# epoch 92, minibatch 250/250, validation error 46.370000 %
# epoch 93, minibatch 250/250, validation error 50.300000 %
# epoch 94, minibatch 250/250, validation error 46.320000 %
# epoch 95, minibatch 250/250, validation error 44.240000 %
# epoch 96, minibatch 250/250, validation error 49.320000 %
# epoch 97, minibatch 250/250, validation error 47.660000 %
# epoch 98, minibatch 250/250, validation error 43.410000 %
# epoch 99, minibatch 250/250, validation error 43.980000 %
# epoch 100, minibatch 250/250, validation error 43.960000 %
# epoch 101, minibatch 250/250, validation error 46.390000 %
# epoch 102, minibatch 250/250, validation error 42.570000 %
#      epoch 102, minibatch 250/250, test error of best model 43.270000 %
# epoch 103, minibatch 250/250, validation error 42.590000 %
# epoch 104, minibatch 250/250, validation error 45.340000 %
# epoch 105, minibatch 250/250, validation error 44.090000 %
# epoch 106, minibatch 250/250, validation error 42.330000 %
#      epoch 106, minibatch 250/250, test error of best model 42.630000 %
# epoch 107, minibatch 250/250, validation error 43.030000 %
# epoch 108, minibatch 250/250, validation error 44.950000 %
# epoch 109, minibatch 250/250, validation error 42.570000 %
# epoch 110, minibatch 250/250, validation error 40.030000 %
#      epoch 110, minibatch 250/250, test error of best model 40.170000 %
# epoch 111, minibatch 250/250, validation error 44.700000 %
# epoch 112, minibatch 250/250, validation error 49.130000 %
# epoch 113, minibatch 250/250, validation error 43.540000 %
# epoch 114, minibatch 250/250, validation error 44.370000 %
# epoch 115, minibatch 250/250, validation error 43.110000 %
# epoch 116, minibatch 250/250, validation error 42.910000 %
# epoch 117, minibatch 250/250, validation error 43.350000 %
# epoch 118, minibatch 250/250, validation error 45.840000 %
# epoch 119, minibatch 250/250, validation error 38.620000 %
#      epoch 119, minibatch 250/250, test error of best model 39.180000 %
# epoch 120, minibatch 250/250, validation error 43.520000 %
# epoch 121, minibatch 250/250, validation error 43.200000 %
# epoch 122, minibatch 250/250, validation error 41.820000 %
# epoch 123, minibatch 250/250, validation error 43.930000 %
# epoch 124, minibatch 250/250, validation error 44.840000 %
# epoch 125, minibatch 250/250, validation error 43.300000 %
# epoch 126, minibatch 250/250, validation error 38.810000 %
# epoch 127, minibatch 250/250, validation error 42.330000 %
# epoch 128, minibatch 250/250, validation error 40.330000 %
# epoch 129, minibatch 250/250, validation error 43.900000 %
# epoch 130, minibatch 250/250, validation error 40.010000 %
# epoch 131, minibatch 250/250, validation error 41.540000 %
# epoch 132, minibatch 250/250, validation error 37.690000 %
#      epoch 132, minibatch 250/250, test error of best model 38.260000 %
# epoch 133, minibatch 250/250, validation error 42.860000 %
# epoch 134, minibatch 250/250, validation error 40.420000 %
# epoch 135, minibatch 250/250, validation error 37.720000 %
# epoch 136, minibatch 250/250, validation error 40.780000 %
# epoch 137, minibatch 250/250, validation error 38.760000 %
# epoch 138, minibatch 250/250, validation error 38.480000 %
# epoch 139, minibatch 250/250, validation error 39.920000 %
# epoch 140, minibatch 250/250, validation error 39.490000 %
# epoch 141, minibatch 250/250, validation error 38.300000 %
# epoch 142, minibatch 250/250, validation error 41.300000 %
# epoch 143, minibatch 250/250, validation error 41.280000 %
# epoch 144, minibatch 250/250, validation error 37.360000 %
#      epoch 144, minibatch 250/250, test error of best model 37.780000 %
# epoch 145, minibatch 250/250, validation error 39.380000 %
# epoch 146, minibatch 250/250, validation error 41.960000 %
# epoch 147, minibatch 250/250, validation error 40.510000 %
# epoch 148, minibatch 250/250, validation error 40.540000 %
# epoch 149, minibatch 250/250, validation error 40.900000 %
# epoch 150, minibatch 250/250, validation error 40.200000 %
# epoch 151, minibatch 250/250, validation error 42.930000 %
# epoch 152, minibatch 250/250, validation error 36.880000 %
#      epoch 152, minibatch 250/250, test error of best model 36.750000 %
# epoch 153, minibatch 250/250, validation error 38.400000 %
# epoch 154, minibatch 250/250, validation error 40.710000 %
# epoch 155, minibatch 250/250, validation error 37.080000 %
# epoch 156, minibatch 250/250, validation error 42.630000 %
# epoch 157, minibatch 250/250, validation error 38.910000 %
# epoch 158, minibatch 250/250, validation error 35.930000 %
#      epoch 158, minibatch 250/250, test error of best model 36.470000 %
# epoch 159, minibatch 250/250, validation error 40.060000 %
# epoch 160, minibatch 250/250, validation error 37.230000 %
# epoch 165, minibatch 250/250, validation error 40.050000 %
# epoch 166, minibatch 250/250, validation error 38.360000 %
# epoch 167, minibatch 250/250, validation error 40.880000 %
# epoch 168, minibatch 250/250, validation error 40.650000 %
# epoch 171, minibatch 250/250, validation error 36.420000 %
# epoch 172, minibatch 250/250, validation error 39.970000 %
# epoch 173, minibatch 250/250, validation error 35.900000 %
#      epoch 173, minibatch 250/250, test error of best model 36.220000 %
# epoch 174, minibatch 250/250, validation error 38.030000 %
# epoch 175, minibatch 250/250, validation error 36.660000 %
# epoch 176, minibatch 250/250, validation error 43.290000 %
# epoch 177, minibatch 250/250, validation error 37.460000 %
# epoch 178, minibatch 250/250, validation error 35.560000 %
#      epoch 178, minibatch 250/250, test error of best model 35.800000 %
# epoch 179, minibatch 250/250, validation error 33.680000 %
#      epoch 179, minibatch 250/250, test error of best model 34.040000 %
# epoch 180, minibatch 250/250, validation error 34.050000 %
# epoch 181, minibatch 250/250, validation error 33.390000 %
#      epoch 181, minibatch 250/250, test error of best model 33.400000 %
# epoch 182, minibatch 250/250, validation error 33.400000 %
# epoch 183, minibatch 250/250, validation error 33.780000 %
# epoch 184, minibatch 250/250, validation error 33.290000 %
# epoch 185, minibatch 250/250, validation error 33.469239 %
# epoch 186, minibatch 250/250, validation error 35.367395 %
# epoch 187, minibatch 250/250, validation error 36.288981 %
# epoch 188, minibatch 250/250, validation error 33.816471 %
# epoch 189, minibatch 250/250, validation error 32.810000 %
#      epoch 189, minibatch 250/250, test error of best model 32.800000 %
# epoch 190, minibatch 250/250, validation error 32.130000 %
#      epoch 190, minibatch 250/250, test error of best model 32.390000 %
# epoch 191, minibatch 250/250, validation error 31.790000 %
# epoch 192, minibatch 250/250, validation error 31.700000 %
#      epoch 192, minibatch 250/250, test error of best model 32.700000 %
# epoch 193, minibatch 250/250, validation error 31.300000 %
#      epoch 193, minibatch 250/250, test error of best model 32.820000 %
# epoch 194, minibatch 250/250, validation error 31.430000 %
# epoch 195, minibatch 250/250, validation error 31.310000 %
# epoch 196, minibatch 250/250, validation error 31.100000 %
# epoch 197, minibatch 250/250, validation error 31.270000 %
# epoch 198, minibatch 250/250, validation error 30.610000 %
#      epoch 198, minibatch 250/250, test error of best model 32.210000 %
# epoch 199, minibatch 250/250, validation error 34.103162 %
# epoch 200, minibatch 250/250, validation error 32.305562 %
# epoch 201, minibatch 250/250, validation error 33.050686 %
# epoch 202, minibatch 250/250, validation error 30.560000 %
#      epoch 202, minibatch 250/250, test error of best model 32.250000 %
# epoch 203, minibatch 250/250, validation error 30.350000 %
# epoch 204, minibatch 250/250, validation error 29.980000 %
#      epoch 204, minibatch 250/250, test error of best model 30.870000 %
# epoch 205, minibatch 250/250, validation error 30.120000 %
# epoch 206, minibatch 250/250, validation error 30.220000 %
# epoch 207, minibatch 250/250, validation error 34.377103 %
# epoch 208, minibatch 250/250, validation error 34.251455 %
# epoch 209, minibatch 250/250, validation error 30.222978 %
# epoch 210, minibatch 250/250, validation error 30.071223 %
# epoch 211, minibatch 250/250, validation error 29.600000 %
#      epoch 211, minibatch 250/250, test error of best model 30.060000 %
# epoch 212, minibatch 250/250, validation error 29.090000 %
#      epoch 212, minibatch 250/250, test error of best model 30.310000 %
# epoch 213, minibatch 250/250, validation error 28.590000 %
#      epoch 213, minibatch 250/250, test error of best model 29.210000 %
# epoch 214, minibatch 250/250, validation error 28.650000 %
# epoch 215, minibatch 250/250, validation error 28.680000 %
# epoch 216, minibatch 250/250, validation error 30.224640 %
# epoch 217, minibatch 250/250, validation error 33.138106 %
# epoch 218, minibatch 250/250, validation error 29.919705 %
# epoch 219, minibatch 250/250, validation error 29.319316 %
# epoch 220, minibatch 250/250, validation error 28.660000 %
# epoch 221, minibatch 250/250, validation error 28.660000 %
# epoch 222, minibatch 250/250, validation error 28.680000 %
# epoch 223, minibatch 250/250, validation error 28.190000 %
#      epoch 223, minibatch 250/250, test error of best model 28.570000 %
# epoch 224, minibatch 250/250, validation error 28.420000 %
# epoch 225, minibatch 250/250, validation error 32.784604 %
# epoch 226, minibatch 250/250, validation error 28.240000 %
# epoch 227, minibatch 250/250, validation error 27.990000 %
# epoch 228, minibatch 250/250, validation error 27.740000 %
# epoch 229, minibatch 250/250, validation error 27.880000 %
# epoch 230, minibatch 250/250, validation error 27.480000 %
# epoch 231, minibatch 250/250, validation error 27.350000 %
# epoch 232, minibatch 250/250, validation error 27.220000 %
#      epoch 232, minibatch 250/250, test error of best model 28.070000 %
# epoch 233, minibatch 250/250, validation error 27.550000 %
# epoch 234, minibatch 250/250, validation error 27.300000 %
# epoch 235, minibatch 250/250, validation error 27.550000 %
# epoch 236, minibatch 250/250, validation error 27.280000 %
# epoch 237, minibatch 250/250, validation error 27.460000 %
# epoch 238, minibatch 250/250, validation error 27.200000 %
# epoch 239, minibatch 250/250, validation error 27.210000 %
# epoch 240, minibatch 250/250, validation error 26.740000 %
#      epoch 240, minibatch 250/250, test error of best model 26.710000 %
# epoch 241, minibatch 250/250, validation error 27.469773 %
# epoch 242, minibatch 250/250, validation error 29.751954 %
# epoch 243, minibatch 250/250, validation error 28.205727 %
# epoch 244, minibatch 250/250, validation error 27.520892 %
# epoch 245, minibatch 250/250, validation error 31.440867 %
# epoch 246, minibatch 250/250, validation error 26.890000 %
# epoch 247, minibatch 250/250, validation error 26.690000 %
# epoch 248, minibatch 250/250, validation error 26.760000 %
# epoch 249, minibatch 250/250, validation error 26.290000 %
# epoch 250, minibatch 250/250, validation error 26.040000 %
#      epoch 250, minibatch 250/250, test error of best model 26.150000 %
# epoch 251, minibatch 250/250, validation error 29.695780 %
# epoch 252, minibatch 250/250, validation error 30.027384 %
# epoch 253, minibatch 250/250, validation error 25.670000 %
#      epoch 253, minibatch 250/250, test error of best model 25.610000 %
# epoch 254, minibatch 250/250, validation error 25.060000 %
#      epoch 254, minibatch 250/250, test error of best model 25.280000 %
# epoch 255, minibatch 250/250, validation error 24.920000 %
#      epoch 255, minibatch 250/250, test error of best model 25.530000 %
# epoch 256, minibatch 250/250, validation error 24.910000 %
# epoch 257, minibatch 250/250, validation error 24.660000 %
# epoch 258, minibatch 250/250, validation error 26.136866 %
# epoch 259, minibatch 250/250, validation error 24.320000 %
#      epoch 259, minibatch 250/250, test error of best model 25.030000 %
# epoch 260, minibatch 250/250, validation error 23.630000 %
#      epoch 260, minibatch 250/250, test error of best model 24.150000 %
# epoch 261, minibatch 250/250, validation error 23.240000 %
#      epoch 261, minibatch 250/250, test error of best model 23.950000 %
# epoch 262, minibatch 250/250, validation error 23.050000 %
# epoch 263, minibatch 250/250, validation error 23.060000 %
# epoch 264, minibatch 250/250, validation error 24.560777 %
# epoch 265, minibatch 250/250, validation error 23.139898 %
# epoch 266, minibatch 250/250, validation error 23.823220 %
# epoch 267, minibatch 250/250, validation error 22.540000 %
#      epoch 267, minibatch 250/250, test error of best model 22.370000 %
# epoch 268, minibatch 250/250, validation error 22.680000 %
# epoch 269, minibatch 250/250, validation error 22.600000 %
# epoch 270, minibatch 250/250, validation error 22.910000 %
# epoch 271, minibatch 250/250, validation error 22.330000 %
#      epoch 271, minibatch 250/250, test error of best model 21.810000 %
# epoch 272, minibatch 250/250, validation error 23.733188 %
# epoch 273, minibatch 250/250, validation error 22.390000 %
# epoch 274, minibatch 250/250, validation error 22.270000 %
# epoch 275, minibatch 250/250, validation error 22.510000 %
# epoch 276, minibatch 250/250, validation error 22.350000 %
# epoch 277, minibatch 250/250, validation error 22.060000 %
#      epoch 277, minibatch 250/250, test error of best model 21.550000 %
# epoch 278, minibatch 250/250, validation error 23.015586 %
# epoch 279, minibatch 250/250, validation error 23.619400 %
# epoch 280, minibatch 250/250, validation error 21.770000 %
#      epoch 280, minibatch 250/250, test error of best model 22.060000 %
# epoch 281, minibatch 250/250, validation error 21.130000 %
#      epoch 281, minibatch 250/250, test error of best model 21.500000 %
# epoch 282, minibatch 250/250, validation error 20.850000 %
# epoch 283, minibatch 250/250, validation error 20.320000 %
#      epoch 283, minibatch 250/250, test error of best model 21.320000 %
# epoch 284, minibatch 250/250, validation error 20.460000 %
# epoch 285, minibatch 250/250, validation error 23.413302 %
# epoch 286, minibatch 250/250, validation error 20.853995 %
# epoch 287, minibatch 250/250, validation error 20.200112 %
# epoch 288, minibatch 250/250, validation error 22.491333 %
# epoch 289, minibatch 250/250, validation error 20.738981 %
# epoch 290, minibatch 250/250, validation error 19.910000 %
#      epoch 290, minibatch 250/250, test error of best model 21.230000 %
# epoch 291, minibatch 250/250, validation error 20.230000 %
# epoch 292, minibatch 250/250, validation error 19.560000 %
#      epoch 292, minibatch 250/250, test error of best model 21.070000 %
# epoch 293, minibatch 250/250, validation error 19.900000 %
# epoch 294, minibatch 250/250, validation error 19.380000 %
#      epoch 294, minibatch 250/250, test error of best model 20.680000 %
# epoch 295, minibatch 250/250, validation error 24.197112 %
# epoch 296, minibatch 250/250, validation error 21.819373 %
# epoch 297, minibatch 250/250, validation error 23.236093 %
# epoch 298, minibatch 250/250, validation error 21.646522 %
# epoch 299, minibatch 250/250, validation error 19.370000 %
#      epoch 299, minibatch 250/250, test error of best model 20.760000 %
# epoch 300, minibatch 250/250, validation error 19.590000 %
# epoch 301, minibatch 250/250, validation error 19.420000 %
# epoch 302, minibatch 250/250, validation error 19.540000 %
# epoch 303, minibatch 250/250, validation error 19.680000 %
# epoch 335, minibatch 250/250, validation error 13.570000 %
# epoch 336, minibatch 250/250, validation error 13.350000 %
# epoch 337, minibatch 250/250, validation error 13.390000 %
# epoch 338, minibatch 250/250, validation error 13.400000 %
# epoch 339, minibatch 250/250, validation error 12.710000 %
#      epoch 339, minibatch 250/250, test error of best model 16.220000 %
# epoch 340, minibatch 250/250, validation error 12.590000 %
# epoch 341, minibatch 250/250, validation error 12.570000 %
# epoch 342, minibatch 250/250, validation error 12.880000 %
# epoch 343, minibatch 250/250, validation error 13.128273 %
# epoch 344, minibatch 250/250, validation error 12.640000 %
# epoch 345, minibatch 250/250, validation error 12.420000 %
#      epoch 345, minibatch 250/250, test error of best model 15.070000 %
# epoch 346, minibatch 250/250, validation error 12.190000 %
#      epoch 346, minibatch 250/250, test error of best model 14.740000 %
# epoch 347, minibatch 250/250, validation error 11.950000 %
#      epoch 347, minibatch 250/250, test error of best model 14.520000 %
# epoch 348, minibatch 250/250, validation error 11.690000 %
#      epoch 348, minibatch 250/250, test error of best model 13.670000 %
# epoch 349, minibatch 250/250, validation error 13.130702 %
# epoch 350, minibatch 250/250, validation error 14.492311 %
# Optimization complete.
# Best validation score of 11.690000 % obtained with test performance 13.670000 %

# %% [markdown]
# # Second set of experiments

# %% [markdown]
# # Model ALL-CNN-A With Data Augmentation

# %%
from test_AllCNN_Models_DA_BN import test_AllCNN_Models_DA_BN
test_AllCNN_Models_DA_BN(use_bn=False, model='a')

# %% [markdown]
# Best validation score of 8.280000 % obtained with test performance 12.470000 %

# %% [markdown]
# # Model ALL-CNN-B With Data Augmentation

# %%
from test_AllCNN_Models_DA_BN import test_AllCNN_Models_DA_BN
test_AllCNN_Models_DA_BN(use_bn=False, model='b')

# %% [markdown]
# Best validation score of 6.850000 % obtained with test performance 11.540000 %

# %% [markdown]
# # Model ALL-CNN-C With Data Augmentation

# %%
from test_AllCNN_Models_DA_BN import test_AllCNN_Models_DA_BN
test_AllCNN_Models_DA_BN(use_bn=False, model='c')

# %% [markdown]
# n_train_batches:  250
# n_valid_batches:  50
# n_test_batches:  50
# learning_rate:  0.0500000007451
# ... building the model
# Training Model:  ModelB_AllCNN
# ... training
# epoch 1, minibatch 125/250, validation error 89.910000 %
#      epoch 1, minibatch 125/250, test error of best model 89.880000 %
# epoch 1, minibatch 250/250, validation error 89.860000 %
#      epoch 1, minibatch 250/250, test error of best model 90.000000 %
# epoch 2, minibatch 125/250, validation error 81.890000 %
#      epoch 2, minibatch 125/250, test error of best model 81.940000 %
# epoch 2, minibatch 250/250, validation error 82.390000 %
# epoch 3, minibatch 125/250, validation error 81.870000 %
#      epoch 3, minibatch 125/250, test error of best model 81.160000 %
# epoch 3, minibatch 250/250, validation error 80.840000 %
#      epoch 3, minibatch 250/250, test error of best model 80.430000 %
# epoch 4, minibatch 125/250, validation error 80.490000 %
#      epoch 4, minibatch 125/250, test error of best model 79.490000 %
# epoch 4, minibatch 250/250, validation error 81.060000 %
# epoch 5, minibatch 125/250, validation error 78.610000 %
#      epoch 5, minibatch 125/250, test error of best model 78.170000 %
# epoch 5, minibatch 250/250, validation error 78.690000 %
# epoch 6, minibatch 125/250, validation error 77.480000 %
#      epoch 6, minibatch 125/250, test error of best model 77.050000 %
# epoch 6, minibatch 250/250, validation error 78.250000 %
# epoch 7, minibatch 125/250, validation error 75.910000 %
#      epoch 7, minibatch 125/250, test error of best model 76.370000 %
# epoch 7, minibatch 250/250, validation error 78.670000 %
# epoch 8, minibatch 125/250, validation error 77.530000 %
# epoch 8, minibatch 250/250, validation error 75.720000 %
#      epoch 8, minibatch 250/250, test error of best model 75.680000 %
# epoch 9, minibatch 125/250, validation error 75.110000 %
#      epoch 9, minibatch 125/250, test error of best model 75.020000 %
# epoch 9, minibatch 250/250, validation error 76.890000 %
# epoch 10, minibatch 125/250, validation error 75.700000 %
# epoch 10, minibatch 250/250, validation error 72.900000 %
#      epoch 10, minibatch 250/250, test error of best model 73.210000 %
# epoch 11, minibatch 125/250, validation error 77.050000 %
# epoch 11, minibatch 250/250, validation error 70.990000 %
#      epoch 11, minibatch 250/250, test error of best model 71.000000 %
# epoch 12, minibatch 125/250, validation error 78.060000 %
# epoch 12, minibatch 250/250, validation error 71.530000 %
# epoch 13, minibatch 125/250, validation error 76.180000 %
# epoch 13, minibatch 250/250, validation error 70.310000 %
#      epoch 13, minibatch 250/250, test error of best model 69.800000 %
# epoch 14, minibatch 125/250, validation error 69.080000 %
#      epoch 14, minibatch 125/250, test error of best model 69.700000 %
# epoch 14, minibatch 250/250, validation error 71.900000 %
# epoch 15, minibatch 125/250, validation error 65.890000 %
#      epoch 15, minibatch 125/250, test error of best model 65.860000 %
# epoch 15, minibatch 250/250, validation error 71.330000 %
# epoch 16, minibatch 125/250, validation error 66.560000 %
# epoch 16, minibatch 250/250, validation error 69.790000 %
# epoch 17, minibatch 125/250, validation error 68.190000 %
# epoch 17, minibatch 250/250, validation error 67.670000 %
# epoch 18, minibatch 125/250, validation error 67.450000 %
# epoch 18, minibatch 250/250, validation error 70.980000 %
# epoch 19, minibatch 125/250, validation error 65.530000 %
#      epoch 19, minibatch 125/250, test error of best model 65.420000 %
# epoch 19, minibatch 250/250, validation error 70.800000 %
# epoch 20, minibatch 125/250, validation error 70.440000 %
# epoch 20, minibatch 250/250, validation error 64.670000 %
#      epoch 20, minibatch 250/250, test error of best model 64.550000 %
# epoch 21, minibatch 125/250, validation error 65.350000 %
# epoch 21, minibatch 250/250, validation error 66.250000 %
# epoch 22, minibatch 125/250, validation error 62.780000 %
#      epoch 22, minibatch 125/250, test error of best model 63.190000 %
# epoch 22, minibatch 250/250, validation error 63.670000 %
# epoch 23, minibatch 125/250, validation error 64.540000 %
# epoch 23, minibatch 250/250, validation error 64.180000 %
# epoch 24, minibatch 125/250, validation error 65.650000 %
# epoch 24, minibatch 250/250, validation error 64.480000 %
# epoch 25, minibatch 125/250, validation error 61.860000 %
#      epoch 25, minibatch 125/250, test error of best model 62.040000 %
# epoch 25, minibatch 250/250, validation error 66.500000 %
# epoch 26, minibatch 125/250, validation error 63.830000 %
# epoch 26, minibatch 250/250, validation error 63.770000 %
# epoch 27, minibatch 125/250, validation error 66.450000 %
# epoch 27, minibatch 250/250, validation error 58.150000 %
#      epoch 27, minibatch 250/250, test error of best model 58.910000 %
# epoch 28, minibatch 125/250, validation error 68.360000 %
# epoch 28, minibatch 250/250, validation error 59.600000 %
# epoch 29, minibatch 125/250, validation error 61.510000 %
# epoch 29, minibatch 250/250, validation error 64.070000 %
# epoch 30, minibatch 125/250, validation error 60.860000 %
# epoch 30, minibatch 250/250, validation error 64.580000 %
# epoch 31, minibatch 125/250, validation error 67.420000 %
# epoch 31, minibatch 250/250, validation error 61.450000 %
# epoch 32, minibatch 125/250, validation error 58.880000 %
# epoch 32, minibatch 250/250, validation error 60.310000 %
# epoch 33, minibatch 125/250, validation error 62.810000 %
# epoch 33, minibatch 250/250, validation error 57.080000 %
#      epoch 33, minibatch 250/250, test error of best model 57.000000 %
# epoch 34, minibatch 125/250, validation error 60.780000 %
# epoch 34, minibatch 250/250, validation error 62.580000 %
# epoch 35, minibatch 125/250, validation error 57.090000 %
# epoch 35, minibatch 250/250, validation error 60.120000 %
# epoch 40, minibatch 125/250, validation error 59.740000 %
# epoch 40, minibatch 250/250, validation error 57.970000 %
# epoch 41, minibatch 125/250, validation error 58.520000 %
# epoch 41, minibatch 250/250, validation error 58.190000 %
# epoch 42, minibatch 125/250, validation error 60.260000 %
# epoch 42, minibatch 250/250, validation error 56.330000 %
# epoch 43, minibatch 125/250, validation error 58.780000 %
# epoch 43, minibatch 250/250, validation error 55.830000 %
#      epoch 43, minibatch 250/250, test error of best model 56.620000 %
# epoch 44, minibatch 125/250, validation error 57.480000 %
# epoch 44, minibatch 250/250, validation error 58.340000 %
# epoch 45, minibatch 125/250, validation error 55.620000 %
#      epoch 45, minibatch 125/250, test error of best model 55.880000 %
# epoch 45, minibatch 250/250, validation error 57.770000 %
# epoch 46, minibatch 125/250, validation error 53.580000 %
#      epoch 46, minibatch 125/250, test error of best model 53.540000 %
# epoch 49, minibatch 250/250, validation error 54.900000 %
# epoch 50, minibatch 125/250, validation error 53.470000 %
# epoch 50, minibatch 250/250, validation error 55.540000 %
# epoch 51, minibatch 125/250, validation error 53.550000 %
# epoch 51, minibatch 250/250, validation error 55.200000 %
# epoch 52, minibatch 125/250, validation error 53.510000 %
# epoch 52, minibatch 250/250, validation error 56.940000 %
# epoch 53, minibatch 125/250, validation error 54.090000 %
# epoch 53, minibatch 250/250, validation error 52.000000 %
#      epoch 53, minibatch 250/250, test error of best model 52.660000 %
# epoch 54, minibatch 125/250, validation error 52.690000 %
# epoch 54, minibatch 250/250, validation error 53.020000 %
# epoch 55, minibatch 125/250, validation error 54.730000 %
# epoch 55, minibatch 250/250, validation error 52.150000 %
# epoch 56, minibatch 125/250, validation error 55.760000 %
# epoch 56, minibatch 250/250, validation error 50.790000 %
#      epoch 56, minibatch 250/250, test error of best model 51.410000 %
# epoch 57, minibatch 125/250, validation error 52.630000 %
# epoch 57, minibatch 250/250, validation error 52.750000 %
# epoch 60, minibatch 250/250, validation error 47.830000 %
#      epoch 60, minibatch 250/250, test error of best model 48.950000 %
# epoch 61, minibatch 125/250, validation error 49.200000 %
# epoch 61, minibatch 250/250, validation error 47.980000 %
# epoch 62, minibatch 125/250, validation error 51.880000 %
# epoch 64, minibatch 250/250, validation error 50.400000 %
# epoch 65, minibatch 125/250, validation error 49.730000 %
# epoch 65, minibatch 250/250, validation error 46.530000 %
#      epoch 65, minibatch 250/250, test error of best model 47.270000 %
# epoch 66, minibatch 125/250, validation error 49.860000 %
# epoch 66, minibatch 250/250, validation error 48.730000 %
# epoch 67, minibatch 125/250, validation error 52.810000 %
# epoch 67, minibatch 250/250, validation error 51.920000 %
# epoch 68, minibatch 125/250, validation error 47.030000 %
# epoch 68, minibatch 250/250, validation error 57.240000 %
# epoch 69, minibatch 125/250, validation error 47.600000 %
# epoch 69, minibatch 250/250, validation error 47.500000 %
# epoch 70, minibatch 125/250, validation error 46.130000 %
#      epoch 70, minibatch 125/250, test error of best model 47.930000 %
# epoch 70, minibatch 250/250, validation error 47.430000 %
# epoch 71, minibatch 125/250, validation error 48.290000 %
# epoch 71, minibatch 250/250, validation error 45.720000 %
#      epoch 71, minibatch 250/250, test error of best model 46.070000 %
# epoch 72, minibatch 125/250, validation error 46.860000 %
# epoch 72, minibatch 250/250, validation error 48.660000 %
# epoch 73, minibatch 125/250, validation error 49.010000 %
# epoch 73, minibatch 250/250, validation error 55.480000 %
# epoch 74, minibatch 125/250, validation error 50.190000 %
# epoch 74, minibatch 250/250, validation error 48.680000 %
# epoch 75, minibatch 125/250, validation error 51.920000 %
# epoch 75, minibatch 250/250, validation error 44.890000 %
#      epoch 75, minibatch 250/250, test error of best model 45.710000 %
# epoch 76, minibatch 125/250, validation error 45.750000 %
# epoch 76, minibatch 250/250, validation error 43.880000 %
#      epoch 76, minibatch 250/250, test error of best model 45.270000 %
# epoch 77, minibatch 125/250, validation error 50.000000 %
# epoch 77, minibatch 250/250, validation error 54.570000 %
# epoch 78, minibatch 125/250, validation error 48.680000 %
# epoch 78, minibatch 250/250, validation error 42.400000 %
#      epoch 78, minibatch 250/250, test error of best model 44.160000 %
# epoch 79, minibatch 125/250, validation error 46.770000 %
# epoch 79, minibatch 250/250, validation error 44.720000 %
# epoch 80, minibatch 125/250, validation error 45.720000 %
# epoch 80, minibatch 250/250, validation error 44.370000 %
# epoch 81, minibatch 125/250, validation error 43.880000 %
# epoch 81, minibatch 250/250, validation error 43.030000 %
# epoch 82, minibatch 125/250, validation error 45.710000 %
# epoch 82, minibatch 250/250, validation error 45.740000 %
# epoch 83, minibatch 125/250, validation error 47.260000 %
# epoch 83, minibatch 250/250, validation error 47.050000 %
# epoch 84, minibatch 125/250, validation error 43.800000 %
# epoch 84, minibatch 250/250, validation error 42.850000 %
# epoch 85, minibatch 125/250, validation error 43.780000 %
# epoch 85, minibatch 250/250, validation error 44.620000 %
# epoch 86, minibatch 125/250, validation error 42.410000 %
# epoch 86, minibatch 250/250, validation error 41.590000 %
#      epoch 86, minibatch 250/250, test error of best model 42.430000 %
# epoch 87, minibatch 125/250, validation error 42.200000 %
# epoch 87, minibatch 250/250, validation error 42.960000 %
# epoch 88, minibatch 125/250, validation error 40.890000 %
#      epoch 88, minibatch 125/250, test error of best model 41.660000 %
# epoch 88, minibatch 250/250, validation error 45.350000 %
# epoch 89, minibatch 125/250, validation error 41.470000 %
# epoch 89, minibatch 250/250, validation error 44.880000 %
# epoch 90, minibatch 125/250, validation error 39.680000 %
#      epoch 90, minibatch 125/250, test error of best model 41.110000 %
# epoch 90, minibatch 250/250, validation error 41.690000 %
# epoch 91, minibatch 125/250, validation error 41.880000 %
# epoch 91, minibatch 250/250, validation error 41.600000 %
# epoch 92, minibatch 125/250, validation error 39.500000 %
#      epoch 92, minibatch 125/250, test error of best model 41.420000 %
# epoch 92, minibatch 250/250, validation error 46.160000 %
# epoch 93, minibatch 125/250, validation error 43.300000 %
# epoch 93, minibatch 250/250, validation error 42.610000 %
# epoch 94, minibatch 125/250, validation error 41.130000 %
# epoch 94, minibatch 250/250, validation error 40.680000 %
# epoch 95, minibatch 125/250, validation error 43.130000 %
# epoch 95, minibatch 250/250, validation error 40.370000 %
# epoch 96, minibatch 125/250, validation error 40.390000 %
# epoch 96, minibatch 250/250, validation error 42.250000 %
# epoch 97, minibatch 125/250, validation error 45.510000 %
# epoch 97, minibatch 250/250, validation error 45.960000 %
# epoch 98, minibatch 125/250, validation error 42.620000 %
# epoch 98, minibatch 250/250, validation error 45.120000 %
# epoch 99, minibatch 125/250, validation error 39.730000 %
# epoch 99, minibatch 250/250, validation error 37.670000 %
#      epoch 99, minibatch 250/250, test error of best model 39.620000 %
# epoch 100, minibatch 125/250, validation error 40.380000 %
# epoch 100, minibatch 250/250, validation error 43.580000 %
# epoch 101, minibatch 125/250, validation error 42.270000 %
# epoch 101, minibatch 250/250, validation error 41.700000 %
# epoch 102, minibatch 125/250, validation error 42.530000 %
# epoch 102, minibatch 250/250, validation error 37.730000 %
# epoch 103, minibatch 125/250, validation error 40.410000 %
# epoch 103, minibatch 250/250, validation error 40.310000 %
# epoch 104, minibatch 125/250, validation error 44.150000 %
# epoch 104, minibatch 250/250, validation error 43.260000 %
# epoch 105, minibatch 125/250, validation error 38.360000 %
# epoch 105, minibatch 250/250, validation error 45.300000 %
# epoch 106, minibatch 125/250, validation error 37.380000 %
#      epoch 106, minibatch 125/250, test error of best model 38.580000 %
# epoch 106, minibatch 250/250, validation error 43.840000 %
# epoch 107, minibatch 125/250, validation error 40.480000 %
# epoch 107, minibatch 250/250, validation error 43.620000 %
# epoch 108, minibatch 125/250, validation error 42.390000 %
# epoch 108, minibatch 250/250, validation error 42.150000 %
# epoch 109, minibatch 125/250, validation error 40.550000 %
# epoch 109, minibatch 250/250, validation error 36.720000 %
#      epoch 109, minibatch 250/250, test error of best model 38.480000 %
# epoch 110, minibatch 125/250, validation error 43.260000 %
# epoch 110, minibatch 250/250, validation error 42.550000 %
# epoch 111, minibatch 125/250, validation error 42.810000 %
# epoch 111, minibatch 250/250, validation error 39.410000 %
# epoch 112, minibatch 125/250, validation error 42.640000 %
# epoch 112, minibatch 250/250, validation error 45.290000 %
# epoch 113, minibatch 125/250, validation error 37.400000 %
# epoch 113, minibatch 250/250, validation error 44.080000 %
# epoch 114, minibatch 125/250, validation error 36.000000 %
#      epoch 114, minibatch 125/250, test error of best model 38.110000 %
# epoch 114, minibatch 250/250, validation error 41.180000 %
# epoch 115, minibatch 125/250, validation error 42.880000 %
# epoch 115, minibatch 250/250, validation error 36.590000 %
# epoch 116, minibatch 125/250, validation error 40.020000 %
# epoch 116, minibatch 250/250, validation error 42.940000 %
# epoch 117, minibatch 125/250, validation error 40.310000 %
# epoch 117, minibatch 250/250, validation error 43.680000 %
# epoch 118, minibatch 125/250, validation error 39.940000 %
# epoch 118, minibatch 250/250, validation error 39.940000 %
# epoch 119, minibatch 125/250, validation error 44.030000 %
# epoch 119, minibatch 250/250, validation error 46.750000 %
# epoch 120, minibatch 125/250, validation error 39.130000 %
# epoch 120, minibatch 250/250, validation error 41.900000 %
# epoch 121, minibatch 125/250, validation error 37.010000 %
# epoch 121, minibatch 250/250, validation error 46.620000 %
# epoch 122, minibatch 125/250, validation error 41.340000 %
# epoch 122, minibatch 250/250, validation error 38.770000 %
# epoch 123, minibatch 125/250, validation error 40.610000 %
# epoch 123, minibatch 250/250, validation error 43.550000 %
# epoch 124, minibatch 125/250, validation error 48.000000 %
# epoch 124, minibatch 250/250, validation error 39.920000 %
# epoch 125, minibatch 125/250, validation error 38.800000 %
# epoch 125, minibatch 250/250, validation error 41.730000 %
# epoch 126, minibatch 125/250, validation error 40.620000 %
# epoch 126, minibatch 250/250, validation error 37.690000 %
# epoch 127, minibatch 125/250, validation error 34.990000 %
#      epoch 127, minibatch 125/250, test error of best model 37.190000 %
# epoch 127, minibatch 250/250, validation error 40.030000 %
# epoch 128, minibatch 125/250, validation error 37.940000 %
# epoch 128, minibatch 250/250, validation error 40.800000 %
# epoch 129, minibatch 125/250, validation error 37.730000 %
# epoch 129, minibatch 250/250, validation error 42.390000 %
# epoch 130, minibatch 125/250, validation error 41.160000 %
# epoch 130, minibatch 250/250, validation error 35.810000 %
# epoch 131, minibatch 125/250, validation error 35.250000 %
# epoch 131, minibatch 250/250, validation error 44.230000 %
# epoch 132, minibatch 125/250, validation error 39.130000 %
# epoch 132, minibatch 250/250, validation error 39.100000 %
# epoch 133, minibatch 125/250, validation error 40.970000 %
# epoch 133, minibatch 250/250, validation error 38.150000 %
# epoch 134, minibatch 125/250, validation error 42.800000 %
# epoch 134, minibatch 250/250, validation error 39.270000 %
# epoch 135, minibatch 125/250, validation error 40.850000 %
# epoch 135, minibatch 250/250, validation error 34.650000 %
#      epoch 135, minibatch 250/250, test error of best model 37.590000 %
# epoch 136, minibatch 125/250, validation error 39.830000 %
# epoch 136, minibatch 250/250, validation error 34.930000 %
# epoch 137, minibatch 125/250, validation error 37.700000 %
# epoch 137, minibatch 250/250, validation error 41.860000 %
# epoch 138, minibatch 125/250, validation error 34.400000 %
#      epoch 138, minibatch 125/250, test error of best model 36.520000 %
# epoch 138, minibatch 250/250, validation error 39.020000 %
# epoch 142, minibatch 125/250, validation error 38.170000 %
# epoch 142, minibatch 250/250, validation error 34.580000 %
# epoch 143, minibatch 125/250, validation error 32.660000 %
#      epoch 143, minibatch 125/250, test error of best model 34.820000 %
# epoch 143, minibatch 250/250, validation error 38.360000 %
# epoch 144, minibatch 125/250, validation error 36.500000 %
# epoch 144, minibatch 250/250, validation error 35.050000 %
# epoch 146, minibatch 125/250, validation error 36.150000 %
# epoch 146, minibatch 250/250, validation error 35.890000 %
# epoch 147, minibatch 125/250, validation error 32.990000 %
# epoch 147, minibatch 250/250, validation error 41.860000 %
# epoch 148, minibatch 125/250, validation error 37.240000 %
# epoch 148, minibatch 250/250, validation error 38.000000 %
# epoch 149, minibatch 125/250, validation error 34.600000 %
# epoch 149, minibatch 250/250, validation error 42.870000 %
# epoch 150, minibatch 125/250, validation error 36.960000 %
# epoch 150, minibatch 250/250, validation error 37.450000 %
# epoch 151, minibatch 125/250, validation error 36.620000 %
# epoch 151, minibatch 250/250, validation error 37.430000 %
# epoch 152, minibatch 125/250, validation error 34.220000 %
# epoch 152, minibatch 250/250, validation error 34.050000 %
# epoch 153, minibatch 125/250, validation error 37.300000 %
# epoch 153, minibatch 250/250, validation error 35.490000 %
# epoch 328, minibatch 250/250, validation error 11.560000 %
# epoch 329, minibatch 125/250, validation error 11.280000 %
#      epoch 329, minibatch 125/250, test error of best model 10.680000 %
# epoch 329, minibatch 250/250, validation error 11.350000 %
# epoch 330, minibatch 125/250, validation error 11.320000 %
# epoch 330, minibatch 250/250, validation error 11.100000 %
#      epoch 330, minibatch 250/250, test error of best model 11.120000 %
# epoch 331, minibatch 125/250, validation error 10.980000 %
#      epoch 331, minibatch 125/250, test error of best model 10.560000 %
# epoch 331, minibatch 250/250, validation error 11.180000 %
# epoch 332, minibatch 125/250, validation error 10.960000 %
#      epoch 332, minibatch 125/250, test error of best model 10.620000 %
# epoch 332, minibatch 250/250, validation error 10.850000 %
#      epoch 332, minibatch 250/250, test error of best model 10.480000 %
# epoch 333, minibatch 125/250, validation error 10.630000 %
#      epoch 333, minibatch 125/250, test error of best model 10.840000 %
# epoch 333, minibatch 250/250, validation error 10.780000 %
# epoch 334, minibatch 125/250, validation error 10.520000 %
#      epoch 334, minibatch 125/250, test error of best model 10.390000 %
# epoch 334, minibatch 250/250, validation error 10.650000 %
# epoch 335, minibatch 125/250, validation error 10.660000 %
# epoch 335, minibatch 250/250, validation error 10.750000 %
# epoch 336, minibatch 125/250, validation error 10.400000 %
#      epoch 336, minibatch 125/250, test error of best model 10.750000 %
# epoch 336, minibatch 250/250, validation error 10.170000 %
#      epoch 336, minibatch 250/250, test error of best model 10.830000 %
# epoch 337, minibatch 125/250, validation error 10.250000 %
# epoch 337, minibatch 250/250, validation error 10.320000 %
# epoch 338, minibatch 125/250, validation error 10.210000 %
# epoch 338, minibatch 250/250, validation error 10.060000 %
#      epoch 338, minibatch 250/250, test error of best model 10.730000 %
# epoch 339, minibatch 125/250, validation error 10.070000 %
# epoch 339, minibatch 250/250, validation error 9.830000 %
#      epoch 339, minibatch 250/250, test error of best model 10.450000 %
# epoch 340, minibatch 125/250, validation error 10.020000 %
# epoch 340, minibatch 250/250, validation error 9.590000 %
#      epoch 340, minibatch 250/250, test error of best model 10.850000 %
# epoch 341, minibatch 125/250, validation error 9.750000 %
# epoch 341, minibatch 250/250, validation error 9.460000 %
#      epoch 341, minibatch 250/250, test error of best model 10.190000 %
# epoch 342, minibatch 125/250, validation error 9.240000 %
#      epoch 342, minibatch 125/250, test error of best model 10.450000 %
# epoch 342, minibatch 250/250, validation error 9.310000 %
# epoch 343, minibatch 125/250, validation error 9.230000 %
#      epoch 343, minibatch 125/250, test error of best model 10.950000 %
# epoch 343, minibatch 250/250, validation error 9.060000 %
#      epoch 343, minibatch 250/250, test error of best model 10.500000 %
# epoch 344, minibatch 125/250, validation error 9.070000 %
# epoch 344, minibatch 250/250, validation error 9.260000 %
# epoch 345, minibatch 125/250, validation error 8.880000 %
#      epoch 345, minibatch 125/250, test error of best model 10.980000 %
# epoch 345, minibatch 250/250, validation error 8.970000 %
# epoch 346, minibatch 125/250, validation error 8.870000 %
#      epoch 346, minibatch 125/250, test error of best model 10.830000 %
# epoch 346, minibatch 250/250, validation error 8.820000 %
#      epoch 346, minibatch 250/250, test error of best model 10.410000 %
# epoch 347, minibatch 125/250, validation error 9.000000 %
# epoch 347, minibatch 250/250, validation error 8.830000 %
# epoch 348, minibatch 125/250, validation error 8.990000 %
# epoch 348, minibatch 250/250, validation error 8.890000 %
# epoch 349, minibatch 125/250, validation error 9.030000 %
# epoch 349, minibatch 250/250, validation error 8.810000 %
#      epoch 349, minibatch 250/250, test error of best model 10.020000 %
# epoch 350, minibatch 125/250, validation error 8.750000 %
#      epoch 350, minibatch 125/250, test error of best model 10.800000 %
# epoch 350, minibatch 250/250, validation error 8.860000 %
# Optimization complete.
# Best validation score of 8.750000 % obtained with test performance 10.800000 %

# %% [markdown]
# # Third set of experiments

# %% [markdown]
# # Model ALL-CNN-A With Data Augmentation and Batch Normalization

# %%
from test_AllCNN_Models_DA_BN import test_AllCNN_Models_DA_BN
test_AllCNN_Models_DA_BN(use_bn=True, model='a')

# %%
Best validation score of 5.750000 % obtained with test performance 11.710000 %

# %% [markdown]
# # Model ALL-CNN-B With Data Augmentation and Batch Normalization

# %%
from test_AllCNN_Models_DA_BN import test_AllCNN_Models_DA_BN
test_AllCNN_Models_DA_BN(use_bn=True, model='b')

# %%
Best validation score of 5.400000 % obtained with test performance 10.670000 %

# %% [markdown]
# # Model ALL-CNN-C With Data Augmentation and Batch Normalization

# %%
from test_AllCNN_Models_DA_BN import test_AllCNN_Models_DA_BN
test_AllCNN_Models_DA_BN(use_bn=True, model='c')

# %% [markdown]
# n_train_batches:  250
# n_valid_batches:  50
# n_test_batches:  50
# learning_rate:  0.0500000007451
# ... building the model
# Training Model:  ModelC_AllCNN_BN
# ... training
# epoch 1, minibatch 125/250, validation error 75.630000 %
#      epoch 1, minibatch 125/250, test error of best model 75.250000 %
#      epoch 1, minibatch 250/250, test error of best model 67.310000 %
# epoch 2, minibatch 125/250, validation error 62.030000 %
#      epoch 2, minibatch 125/250, test error of best model 62.280000 %
# epoch 2, minibatch 250/250, validation error 57.550000 %
#      epoch 2, minibatch 250/250, test error of best model 58.210000 %
# epoch 3, minibatch 125/250, validation error 53.950000 %
#      epoch 3, minibatch 125/250, test error of best model 54.320000 %
# epoch 3, minibatch 250/250, validation error 51.400000 %
#      epoch 3, minibatch 250/250, test error of best model 52.320000 %
# epoch 4, minibatch 125/250, validation error 48.270000 %
#      epoch 4, minibatch 125/250, test error of best model 48.550000 %
# epoch 4, minibatch 250/250, validation error 45.390000 %
#      epoch 4, minibatch 250/250, test error of best model 46.250000 %
# epoch 5, minibatch 125/250, validation error 44.120000 %
#      epoch 5, minibatch 125/250, test error of best model 44.820000 %
# epoch 5, minibatch 250/250, validation error 40.920000 %
#      epoch 5, minibatch 250/250, test error of best model 41.820000 %
# epoch 6, minibatch 125/250, validation error 39.730000 %
#      epoch 6, minibatch 125/250, test error of best model 40.520000 %
# epoch 6, minibatch 250/250, validation error 38.270000 %
#      epoch 6, minibatch 250/250, test error of best model 39.590000 %
# epoch 7, minibatch 125/250, validation error 36.120000 %
#      epoch 7, minibatch 125/250, test error of best model 37.310000 %
# epoch 7, minibatch 250/250, validation error 34.780000 %
#      epoch 7, minibatch 250/250, test error of best model 36.560000 %
# epoch 8, minibatch 125/250, validation error 34.840000 %
# epoch 8, minibatch 250/250, validation error 31.520000 %
#      epoch 8, minibatch 250/250, test error of best model 33.300000 %
# epoch 9, minibatch 125/250, validation error 32.840000 %
# epoch 9, minibatch 250/250, validation error 30.700000 %
#      epoch 9, minibatch 250/250, test error of best model 32.340000 %
# epoch 10, minibatch 125/250, validation error 30.770000 %
# epoch 10, minibatch 250/250, validation error 29.090000 %
#      epoch 10, minibatch 250/250, test error of best model 30.700000 %
# epoch 11, minibatch 125/250, validation error 29.320000 %
# epoch 11, minibatch 250/250, validation error 27.120000 %
#      epoch 11, minibatch 250/250, test error of best model 29.210000 %
# epoch 12, minibatch 125/250, validation error 28.780000 %
# epoch 12, minibatch 250/250, validation error 26.160000 %
#      epoch 12, minibatch 250/250, test error of best model 27.920000 %
# epoch 13, minibatch 125/250, validation error 27.700000 %
# epoch 13, minibatch 250/250, validation error 25.260000 %
#      epoch 13, minibatch 250/250, test error of best model 27.680000 %
# epoch 14, minibatch 125/250, validation error 27.030000 %
# epoch 14, minibatch 250/250, validation error 24.000000 %
#      epoch 14, minibatch 250/250, test error of best model 26.760000 %
# epoch 15, minibatch 125/250, validation error 25.540000 %
# epoch 15, minibatch 250/250, validation error 22.980000 %
#      epoch 15, minibatch 250/250, test error of best model 25.560000 %
# epoch 16, minibatch 125/250, validation error 24.810000 %
# epoch 16, minibatch 250/250, validation error 22.350000 %
#      epoch 16, minibatch 250/250, test error of best model 25.430000 %
# epoch 17, minibatch 125/250, validation error 23.830000 %
# epoch 17, minibatch 250/250, validation error 21.430000 %
#      epoch 17, minibatch 250/250, test error of best model 24.690000 %
# epoch 18, minibatch 125/250, validation error 22.070000 %
# epoch 18, minibatch 250/250, validation error 19.730000 %
#      epoch 18, minibatch 250/250, test error of best model 23.820000 %
# epoch 19, minibatch 125/250, validation error 22.500000 %
# epoch 19, minibatch 250/250, validation error 19.210000 %
#      epoch 19, minibatch 250/250, test error of best model 22.980000 %
# epoch 20, minibatch 125/250, validation error 20.480000 %
# epoch 20, minibatch 250/250, validation error 18.910000 %
#      epoch 20, minibatch 250/250, test error of best model 22.360000 %
# epoch 21, minibatch 125/250, validation error 20.350000 %
# epoch 21, minibatch 250/250, validation error 18.000000 %
#      epoch 21, minibatch 250/250, test error of best model 21.920000 %
# epoch 22, minibatch 125/250, validation error 19.980000 %
# epoch 22, minibatch 250/250, validation error 17.340000 %
#      epoch 22, minibatch 250/250, test error of best model 21.740000 %
# epoch 23, minibatch 125/250, validation error 18.610000 %
# epoch 23, minibatch 250/250, validation error 16.680000 %
#      epoch 23, minibatch 250/250, test error of best model 20.880000 %
# epoch 24, minibatch 125/250, validation error 19.080000 %
# epoch 24, minibatch 250/250, validation error 16.250000 %
#      epoch 24, minibatch 250/250, test error of best model 20.840000 %
# epoch 25, minibatch 125/250, validation error 17.900000 %
# epoch 25, minibatch 250/250, validation error 16.090000 %
#      epoch 25, minibatch 250/250, test error of best model 20.480000 %
# epoch 26, minibatch 125/250, validation error 17.320000 %
# epoch 26, minibatch 250/250, validation error 14.680000 %
#      epoch 26, minibatch 250/250, test error of best model 19.510000 %
# epoch 27, minibatch 125/250, validation error 16.350000 %
# epoch 27, minibatch 250/250, validation error 14.640000 %
#      epoch 27, minibatch 250/250, test error of best model 19.060000 %
# epoch 28, minibatch 125/250, validation error 17.140000 %
# epoch 28, minibatch 250/250, validation error 14.140000 %
#      epoch 28, minibatch 250/250, test error of best model 19.440000 %
# epoch 29, minibatch 125/250, validation error 15.990000 %
# epoch 29, minibatch 250/250, validation error 13.770000 %
#      epoch 29, minibatch 250/250, test error of best model 18.730000 %
# epoch 30, minibatch 125/250, validation error 14.810000 %
# epoch 30, minibatch 250/250, validation error 14.150000 %
# epoch 31, minibatch 125/250, validation error 15.120000 %
# epoch 31, minibatch 250/250, validation error 13.690000 %
#      epoch 31, minibatch 250/250, test error of best model 18.630000 %
# epoch 32, minibatch 125/250, validation error 13.630000 %
#      epoch 32, minibatch 125/250, test error of best model 18.440000 %
# epoch 32, minibatch 250/250, validation error 13.700000 %
# epoch 33, minibatch 125/250, validation error 13.580000 %
#      epoch 33, minibatch 125/250, test error of best model 18.470000 %
# epoch 33, minibatch 250/250, validation error 13.640000 %
# epoch 34, minibatch 125/250, validation error 13.650000 %
# epoch 34, minibatch 250/250, validation error 13.590000 %
# epoch 35, minibatch 125/250, validation error 13.650000 %
# epoch 35, minibatch 250/250, validation error 13.550000 %
#      epoch 35, minibatch 250/250, test error of best model 18.200000 %
# epoch 36, minibatch 125/250, validation error 13.410000 %
#      epoch 36, minibatch 125/250, test error of best model 17.950000 %
# epoch 36, minibatch 250/250, validation error 13.400000 %
#      epoch 36, minibatch 250/250, test error of best model 17.620000 %
# epoch 37, minibatch 125/250, validation error 13.270000 %
#      epoch 37, minibatch 125/250, test error of best model 17.390000 %
# epoch 37, minibatch 250/250, validation error 13.140000 %
#      epoch 37, minibatch 250/250, test error of best model 17.210000 %
# epoch 38, minibatch 125/250, validation error 13.190000 %
# epoch 38, minibatch 250/250, validation error 13.050000 %
#      epoch 38, minibatch 250/250, test error of best model 17.060000 %
# epoch 39, minibatch 125/250, validation error 13.040000 %
#      epoch 39, minibatch 125/250, test error of best model 16.740000 %
# epoch 39, minibatch 250/250, validation error 13.110000 %
# epoch 40, minibatch 125/250, validation error 13.100000 %
# epoch 40, minibatch 250/250, validation error 12.990000 %
#      epoch 40, minibatch 250/250, test error of best model 16.770000 %
# epoch 41, minibatch 125/250, validation error 13.100000 %
# epoch 41, minibatch 250/250, validation error 12.960000 %
#      epoch 41, minibatch 250/250, test error of best model 16.690000 %
# epoch 42, minibatch 125/250, validation error 13.060000 %
# epoch 42, minibatch 250/250, validation error 12.900000 %
#      epoch 42, minibatch 250/250, test error of best model 17.000000 %
# epoch 43, minibatch 125/250, validation error 12.990000 %
# epoch 43, minibatch 250/250, validation error 12.910000 %
# epoch 44, minibatch 125/250, validation error 13.040000 %
# epoch 44, minibatch 250/250, validation error 12.940000 %
# epoch 45, minibatch 125/250, validation error 13.040000 %
# epoch 45, minibatch 250/250, validation error 12.870000 %
#      epoch 45, minibatch 250/250, test error of best model 16.940000 %
# epoch 46, minibatch 125/250, validation error 12.870000 %
# epoch 46, minibatch 250/250, validation error 12.830000 %
#      epoch 46, minibatch 250/250, test error of best model 16.750000 %
# epoch 47, minibatch 125/250, validation error 12.760000 %
#      epoch 47, minibatch 125/250, test error of best model 16.690000 %
# epoch 47, minibatch 250/250, validation error 12.860000 %
# epoch 48, minibatch 125/250, validation error 12.820000 %
# epoch 48, minibatch 250/250, validation error 12.810000 %
# epoch 49, minibatch 125/250, validation error 12.700000 %
#      epoch 49, minibatch 125/250, test error of best model 16.620000 %
# epoch 49, minibatch 250/250, validation error 12.560000 %
#      epoch 49, minibatch 250/250, test error of best model 16.500000 %
# epoch 50, minibatch 125/250, validation error 12.500000 %
#      epoch 50, minibatch 125/250, test error of best model 16.290000 %
# epoch 50, minibatch 250/250, validation error 12.550000 %
# epoch 51, minibatch 125/250, validation error 12.590000 %
# epoch 51, minibatch 250/250, validation error 12.540000 %
# epoch 52, minibatch 125/250, validation error 12.420000 %
#      epoch 52, minibatch 125/250, test error of best model 16.510000 %
# epoch 52, minibatch 250/250, validation error 12.490000 %
# epoch 53, minibatch 125/250, validation error 12.450000 %
# epoch 53, minibatch 250/250, validation error 12.460000 %
# epoch 54, minibatch 125/250, validation error 12.360000 %
#      epoch 54, minibatch 125/250, test error of best model 16.530000 %
# epoch 54, minibatch 250/250, validation error 12.280000 %
#      epoch 54, minibatch 250/250, test error of best model 16.610000 %
# epoch 55, minibatch 125/250, validation error 12.220000 %
#      epoch 55, minibatch 125/250, test error of best model 16.400000 %
# epoch 55, minibatch 250/250, validation error 12.130000 %
#      epoch 55, minibatch 250/250, test error of best model 16.580000 %
# epoch 56, minibatch 125/250, validation error 12.150000 %
# epoch 56, minibatch 250/250, validation error 11.980000 %
#      epoch 56, minibatch 250/250, test error of best model 16.510000 %
# epoch 57, minibatch 125/250, validation error 11.960000 %
#      epoch 57, minibatch 125/250, test error of best model 16.570000 %
# epoch 57, minibatch 250/250, validation error 12.050000 %
# epoch 58, minibatch 125/250, validation error 12.060000 %
# epoch 58, minibatch 250/250, validation error 12.010000 %
# epoch 59, minibatch 125/250, validation error 12.060000 %
# epoch 59, minibatch 250/250, validation error 11.890000 %
#      epoch 59, minibatch 250/250, test error of best model 15.980000 %
# epoch 60, minibatch 125/250, validation error 11.760000 %
#      epoch 60, minibatch 125/250, test error of best model 15.770000 %
# epoch 60, minibatch 250/250, validation error 11.860000 %
# epoch 61, minibatch 125/250, validation error 11.790000 %
# epoch 61, minibatch 250/250, validation error 11.680000 %
#      epoch 61, minibatch 250/250, test error of best model 15.940000 %
# epoch 62, minibatch 125/250, validation error 11.800000 %
# epoch 62, minibatch 250/250, validation error 11.680000 %
# epoch 63, minibatch 125/250, validation error 11.550000 %
#      epoch 63, minibatch 125/250, test error of best model 15.460000 %
# epoch 63, minibatch 250/250, validation error 11.560000 %
# epoch 64, minibatch 125/250, validation error 11.590000 %
# epoch 64, minibatch 250/250, validation error 11.520000 %
#      epoch 64, minibatch 250/250, test error of best model 15.760000 %
# epoch 65, minibatch 125/250, validation error 11.550000 %
# epoch 65, minibatch 250/250, validation error 11.620000 %
# epoch 66, minibatch 125/250, validation error 11.380000 %
#      epoch 66, minibatch 125/250, test error of best model 15.400000 %
# epoch 66, minibatch 250/250, validation error 11.510000 %
# epoch 67, minibatch 125/250, validation error 11.410000 %
# epoch 67, minibatch 250/250, validation error 11.330000 %
#      epoch 67, minibatch 250/250, test error of best model 15.680000 %
# epoch 68, minibatch 125/250, validation error 11.400000 %
# epoch 68, minibatch 250/250, validation error 11.340000 %
# epoch 69, minibatch 125/250, validation error 11.460000 %
# epoch 69, minibatch 250/250, validation error 11.370000 %
# epoch 70, minibatch 125/250, validation error 11.310000 %
#      epoch 70, minibatch 125/250, test error of best model 15.150000 %
# epoch 70, minibatch 250/250, validation error 11.270000 %
#      epoch 70, minibatch 250/250, test error of best model 15.320000 %
# epoch 71, minibatch 125/250, validation error 11.130000 %
#      epoch 71, minibatch 125/250, test error of best model 15.340000 %
# epoch 71, minibatch 250/250, validation error 11.260000 %
# epoch 72, minibatch 125/250, validation error 11.230000 %
# epoch 72, minibatch 250/250, validation error 11.240000 %
# epoch 73, minibatch 125/250, validation error 11.120000 %
#      epoch 73, minibatch 125/250, test error of best model 15.260000 %
# epoch 73, minibatch 250/250, validation error 11.030000 %
#      epoch 73, minibatch 250/250, test error of best model 15.500000 %
# epoch 74, minibatch 125/250, validation error 11.180000 %
# epoch 74, minibatch 250/250, validation error 10.910000 %
#      epoch 74, minibatch 250/250, test error of best model 15.340000 %
# epoch 75, minibatch 125/250, validation error 11.020000 %
# epoch 75, minibatch 250/250, validation error 10.900000 %
#      epoch 75, minibatch 250/250, test error of best model 15.280000 %
# epoch 76, minibatch 125/250, validation error 10.940000 %
# epoch 76, minibatch 250/250, validation error 10.960000 %
# epoch 77, minibatch 125/250, validation error 11.040000 %
# epoch 77, minibatch 250/250, validation error 10.940000 %
# epoch 78, minibatch 125/250, validation error 11.050000 %
# epoch 78, minibatch 250/250, validation error 10.920000 %
# epoch 79, minibatch 125/250, validation error 10.970000 %
# epoch 79, minibatch 250/250, validation error 10.940000 %
# epoch 80, minibatch 125/250, validation error 10.880000 %
#      epoch 80, minibatch 125/250, test error of best model 15.190000 %
# epoch 80, minibatch 250/250, validation error 10.780000 %
#      epoch 80, minibatch 250/250, test error of best model 15.070000 %
# epoch 81, minibatch 125/250, validation error 10.910000 %
# epoch 81, minibatch 250/250, validation error 10.910000 %
# epoch 82, minibatch 125/250, validation error 10.740000 %
#      epoch 82, minibatch 125/250, test error of best model 14.770000 %
# epoch 82, minibatch 250/250, validation error 10.870000 %
# epoch 83, minibatch 125/250, validation error 10.760000 %
# epoch 83, minibatch 250/250, validation error 10.770000 %
# epoch 84, minibatch 125/250, validation error 10.600000 %
#      epoch 84, minibatch 125/250, test error of best model 14.800000 %
# epoch 84, minibatch 250/250, validation error 10.550000 %
#      epoch 84, minibatch 250/250, test error of best model 14.960000 %
# epoch 85, minibatch 125/250, validation error 10.610000 %
# epoch 85, minibatch 250/250, validation error 10.470000 %
#      epoch 85, minibatch 250/250, test error of best model 14.730000 %
# epoch 86, minibatch 125/250, validation error 10.470000 %
# epoch 86, minibatch 250/250, validation error 10.410000 %
#      epoch 86, minibatch 250/250, test error of best model 14.610000 %
# epoch 87, minibatch 125/250, validation error 10.520000 %
# epoch 87, minibatch 250/250, validation error 10.320000 %
#      epoch 87, minibatch 250/250, test error of best model 14.780000 %
# epoch 88, minibatch 125/250, validation error 10.420000 %
# epoch 88, minibatch 250/250, validation error 10.440000 %
# epoch 89, minibatch 125/250, validation error 10.270000 %
#      epoch 89, minibatch 125/250, test error of best model 14.340000 %
# epoch 89, minibatch 250/250, validation error 10.240000 %
#      epoch 89, minibatch 250/250, test error of best model 13.990000 %
# epoch 90, minibatch 125/250, validation error 10.090000 %
#      epoch 90, minibatch 125/250, test error of best model 13.840000 %
# epoch 90, minibatch 250/250, validation error 9.990000 %
#      epoch 90, minibatch 250/250, test error of best model 13.680000 %
# epoch 91, minibatch 125/250, validation error 10.120000 %
# epoch 91, minibatch 250/250, validation error 10.020000 %
# epoch 92, minibatch 125/250, validation error 9.940000 %
#      epoch 92, minibatch 125/250, test error of best model 13.740000 %
# epoch 92, minibatch 250/250, validation error 10.070000 %
# epoch 93, minibatch 125/250, validation error 9.930000 %
#      epoch 93, minibatch 125/250, test error of best model 13.680000 %
# epoch 93, minibatch 250/250, validation error 9.790000 %
#      epoch 93, minibatch 250/250, test error of best model 13.920000 %
# epoch 94, minibatch 125/250, validation error 9.920000 %
# epoch 94, minibatch 250/250, validation error 9.790000 %
# epoch 95, minibatch 125/250, validation error 9.710000 %
#      epoch 95, minibatch 125/250, test error of best model 13.950000 %
# epoch 95, minibatch 250/250, validation error 9.800000 %
# epoch 96, minibatch 125/250, validation error 9.590000 %
#      epoch 96, minibatch 125/250, test error of best model 13.730000 %
# epoch 96, minibatch 250/250, validation error 9.480000 %
#      epoch 96, minibatch 250/250, test error of best model 13.830000 %
# epoch 97, minibatch 125/250, validation error 9.550000 %
# epoch 97, minibatch 250/250, validation error 9.350000 %
#      epoch 97, minibatch 250/250, test error of best model 13.380000 %
# epoch 98, minibatch 125/250, validation error 9.420000 %
# epoch 98, minibatch 250/250, validation error 9.460000 %
# epoch 99, minibatch 125/250, validation error 9.380000 %
# epoch 99, minibatch 250/250, validation error 9.410000 %
# epoch 100, minibatch 125/250, validation error 9.400000 %
# epoch 100, minibatch 250/250, validation error 9.230000 %
#      epoch 100, minibatch 250/250, test error of best model 13.700000 %
# epoch 101, minibatch 125/250, validation error 9.290000 %
# epoch 101, minibatch 250/250, validation error 9.330000 %
# epoch 102, minibatch 125/250, validation error 9.130000 %
#      epoch 102, minibatch 125/250, test error of best model 13.110000 %
# epoch 102, minibatch 250/250, validation error 9.260000 %
# epoch 103, minibatch 125/250, validation error 9.170000 %
# epoch 103, minibatch 250/250, validation error 9.050000 %
#      epoch 103, minibatch 250/250, test error of best model 12.850000 %
# epoch 104, minibatch 125/250, validation error 8.970000 %
#      epoch 104, minibatch 125/250, test error of best model 12.670000 %
# epoch 104, minibatch 250/250, validation error 9.050000 %
# epoch 105, minibatch 125/250, validation error 8.940000 %
#      epoch 105, minibatch 125/250, test error of best model 12.560000 %
# epoch 105, minibatch 250/250, validation error 8.820000 %
#      epoch 105, minibatch 250/250, test error of best model 12.740000 %
# epoch 106, minibatch 125/250, validation error 8.750000 %
#      epoch 106, minibatch 125/250, test error of best model 12.740000 %
# epoch 106, minibatch 250/250, validation error 8.660000 %
#      epoch 106, minibatch 250/250, test error of best model 12.380000 %
# epoch 107, minibatch 125/250, validation error 8.770000 %
# epoch 107, minibatch 250/250, validation error 8.720000 %
# epoch 108, minibatch 125/250, validation error 8.530000 %
#      epoch 108, minibatch 125/250, test error of best model 12.690000 %
# epoch 108, minibatch 250/250, validation error 8.660000 %
# epoch 109, minibatch 125/250, validation error 8.510000 %
#      epoch 109, minibatch 125/250, test error of best model 12.460000 %
# epoch 109, minibatch 250/250, validation error 8.470000 %
#      epoch 109, minibatch 250/250, test error of best model 12.050000 %
# epoch 110, minibatch 125/250, validation error 8.610000 %
# epoch 110, minibatch 250/250, validation error 8.500000 %
# epoch 111, minibatch 125/250, validation error 8.360000 %
#      epoch 111, minibatch 125/250, test error of best model 12.150000 %
# epoch 111, minibatch 250/250, validation error 8.380000 %
# epoch 112, minibatch 125/250, validation error 8.370000 %
# epoch 112, minibatch 250/250, validation error 8.420000 %
# epoch 113, minibatch 125/250, validation error 8.230000 %
#      epoch 113, minibatch 125/250, test error of best model 12.140000 %
# epoch 113, minibatch 250/250, validation error 8.250000 %
# epoch 114, minibatch 125/250, validation error 8.230000 %
# epoch 114, minibatch 250/250, validation error 8.120000 %
#      epoch 114, minibatch 250/250, test error of best model 12.200000 %
# epoch 115, minibatch 125/250, validation error 8.030000 %
#      epoch 115, minibatch 125/250, test error of best model 11.930000 %
# epoch 115, minibatch 250/250, validation error 8.110000 %
# epoch 116, minibatch 125/250, validation error 8.090000 %
# epoch 116, minibatch 250/250, validation error 7.880000 %
#      epoch 116, minibatch 250/250, test error of best model 11.940000 %
# epoch 117, minibatch 125/250, validation error 7.820000 %
#      epoch 117, minibatch 125/250, test error of best model 11.730000 %
# epoch 117, minibatch 250/250, validation error 7.770000 %
#      epoch 117, minibatch 250/250, test error of best model 11.480000 %
# epoch 118, minibatch 125/250, validation error 7.840000 %
# epoch 118, minibatch 250/250, validation error 7.850000 %
# epoch 119, minibatch 125/250, validation error 7.750000 %
#      epoch 119, minibatch 125/250, test error of best model 11.730000 %
# epoch 119, minibatch 250/250, validation error 7.770000 %
# epoch 120, minibatch 125/250, validation error 7.890000 %
# epoch 120, minibatch 250/250, validation error 7.770000 %
# epoch 121, minibatch 125/250, validation error 7.860000 %
# epoch 121, minibatch 250/250, validation error 7.710000 %
#      epoch 121, minibatch 250/250, test error of best model 11.820000 %
# epoch 122, minibatch 125/250, validation error 7.780000 %
# epoch 122, minibatch 250/250, validation error 7.790000 %
# epoch 123, minibatch 125/250, validation error 7.740000 %
# epoch 123, minibatch 250/250, validation error 7.790000 %
# epoch 124, minibatch 125/250, validation error 7.790000 %
# epoch 124, minibatch 250/250, validation error 7.700000 %
#      epoch 124, minibatch 250/250, test error of best model 11.290000 %
# epoch 125, minibatch 125/250, validation error 7.750000 %
# epoch 125, minibatch 250/250, validation error 7.590000 %
#      epoch 125, minibatch 250/250, test error of best model 11.530000 %
# epoch 126, minibatch 125/250, validation error 7.460000 %
#      epoch 126, minibatch 125/250, test error of best model 11.410000 %
# epoch 126, minibatch 250/250, validation error 7.450000 %
#      epoch 126, minibatch 250/250, test error of best model 11.220000 %
# epoch 127, minibatch 125/250, validation error 7.300000 %
#      epoch 127, minibatch 125/250, test error of best model 11.450000 %
# epoch 127, minibatch 250/250, validation error 7.450000 %
# epoch 128, minibatch 125/250, validation error 7.300000 %
# epoch 128, minibatch 250/250, validation error 7.260000 %
#      epoch 128, minibatch 250/250, test error of best model 11.490000 %
# epoch 129, minibatch 125/250, validation error 7.150000 %
#      epoch 129, minibatch 125/250, test error of best model 11.440000 %
# epoch 129, minibatch 250/250, validation error 7.150000 %
# epoch 130, minibatch 125/250, validation error 7.080000 %
#      epoch 130, minibatch 125/250, test error of best model 11.160000 %
# epoch 130, minibatch 250/250, validation error 7.180000 %
# epoch 131, minibatch 125/250, validation error 6.990000 %
#      epoch 131, minibatch 125/250, test error of best model 10.870000 %
# epoch 131, minibatch 250/250, validation error 6.990000 %
# epoch 132, minibatch 125/250, validation error 7.130000 %
# epoch 132, minibatch 250/250, validation error 6.990000 %
# epoch 133, minibatch 125/250, validation error 6.990000 %
# epoch 133, minibatch 250/250, validation error 6.860000 %
#      epoch 133, minibatch 250/250, test error of best model 11.070000 %
# epoch 134, minibatch 125/250, validation error 6.970000 %
# epoch 134, minibatch 250/250, validation error 6.760000 %
#      epoch 134, minibatch 250/250, test error of best model 11.140000 %
# epoch 135, minibatch 125/250, validation error 6.890000 %
# epoch 135, minibatch 250/250, validation error 6.860000 %
# epoch 136, minibatch 125/250, validation error 6.880000 %
# epoch 136, minibatch 250/250, validation error 6.860000 %
# epoch 137, minibatch 125/250, validation error 6.790000 %
# epoch 137, minibatch 250/250, validation error 6.640000 %
#      epoch 137, minibatch 250/250, test error of best model 11.120000 %
# epoch 138, minibatch 125/250, validation error 6.640000 %
# epoch 138, minibatch 250/250, validation error 6.500000 %
#      epoch 138, minibatch 250/250, test error of best model 10.680000 %
# epoch 139, minibatch 125/250, validation error 6.400000 %
#      epoch 139, minibatch 125/250, test error of best model 10.940000 %
# epoch 139, minibatch 250/250, validation error 6.350000 %
#      epoch 139, minibatch 250/250, test error of best model 11.020000 %
# epoch 140, minibatch 125/250, validation error 6.330000 %
#      epoch 140, minibatch 125/250, test error of best model 10.340000 %
# epoch 140, minibatch 250/250, validation error 6.210000 %
#      epoch 140, minibatch 250/250, test error of best model 10.590000 %
# epoch 141, minibatch 125/250, validation error 6.180000 %
#      epoch 141, minibatch 125/250, test error of best model 10.310000 %
# epoch 141, minibatch 250/250, validation error 6.130000 %
#      epoch 141, minibatch 250/250, test error of best model 10.060000 %
# epoch 142, minibatch 125/250, validation error 6.070000 %
#      epoch 142, minibatch 125/250, test error of best model 10.230000 %
# epoch 142, minibatch 250/250, validation error 6.110000 %
# epoch 143, minibatch 125/250, validation error 5.990000 %
#      epoch 143, minibatch 125/250, test error of best model 10.240000 %
# epoch 143, minibatch 250/250, validation error 5.970000 %
#      epoch 143, minibatch 250/250, test error of best model 9.970000 %
# epoch 144, minibatch 125/250, validation error 6.110000 %
# epoch 144, minibatch 250/250, validation error 6.070000 %
# epoch 145, minibatch 125/250, validation error 6.030000 %
# epoch 145, minibatch 250/250, validation error 6.090000 %
# epoch 146, minibatch 125/250, validation error 5.840000 %
#      epoch 146, minibatch 125/250, test error of best model 9.870000 %
# epoch 146, minibatch 250/250, validation error 5.730000 %
#      epoch 146, minibatch 250/250, test error of best model 9.880000 %
# epoch 147, minibatch 125/250, validation error 5.880000 %
# epoch 147, minibatch 250/250, validation error 5.660000 %
#      epoch 147, minibatch 250/250, test error of best model 9.530000 %
# epoch 148, minibatch 125/250, validation error 5.510000 %
#      epoch 148, minibatch 125/250, test error of best model 9.480000 %
# epoch 148, minibatch 250/250, validation error 5.500000 %
#      epoch 148, minibatch 250/250, test error of best model 9.510000 %
# epoch 149, minibatch 125/250, validation error 5.590000 %
# epoch 149, minibatch 250/250, validation error 5.550000 %
# epoch 150, minibatch 125/250, validation error 5.530000 %
# epoch 150, minibatch 250/250, validation error 5.600000 %
# Optimization complete.
# Best validation score of 5.500000 % obtained with test performance 9.510000 %
